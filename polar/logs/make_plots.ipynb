# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
log_n = int(open('./2024-05-30/logs/last_log.txt', 'rt', encoding='utf8').read())
log_n -= 2
logname = os.path.join('./logs', str(log_n) + 'log.csv')
logname
# Out:
# './logs/6log.csv'

# %%
data = pd.read_csv(logname)
data
# Out:
#            t   error_x     alpha         y   error_y         x  angular_error
# 0   0.093032  1.000000  0.000000  0.000000  0.000000  0.000000       0.000000
# 1   0.116184  1.000000  0.000288  0.000000  0.000000  0.000058       0.000000
# 2   0.137035  0.999942  0.001224  0.000000  0.000000  0.000443      -0.000288
# 3   0.152953  0.999557  0.000864 -0.000001 -0.000000  0.003767      -0.001224
# 4   0.169338  0.996233 -0.001728 -0.000003  0.000001  0.010782      -0.000864
# 5   0.187119  0.989218 -0.005616 -0.000001  0.000003  0.019744       0.001728
# 6   0.203136  0.980256 -0.009935  0.000014  0.000001  0.030215       0.005616
# 7   0.219704  0.969785 -0.013535  0.000042 -0.000014  0.041791       0.009935
# 8   0.237595  0.958209 -0.016559  0.000077 -0.000042  0.054358       0.013535
# 9   0.253283  0.945642 -0.018719  0.000108 -0.000077  0.067695       0.016559
# 10  0.270027  0.932305 -0.019367  0.000119 -0.000108  0.081591       0.018719
# ...

# %%
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.grid(True)
plt.scatter(data['x'], data['y'],s=4)
plt.show()

# %%
plt.plot(data['t'], data['error_x'])
plt.show()
